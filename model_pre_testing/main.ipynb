# %% [markdown]
# # **PRE-MODEL TESTING**

# %% [markdown]
# ### **1) REQUIREMENTS SETUP**

# %%
# !pip install -r requirements.txt

# %%
import warnings
warnings.filterwarnings("ignore")
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ### **2) MODULES IMPORT**

# %%
# None so far

# %% [markdown]
# ### **3) LOREM IPSUM**

# %%
# Lorem Ipsum
